# %% [markdown]
# <a href="https://colab.research.google.com/github/surendra3474/takeobds41/blob/main/EDA_IMDB_Low_Ranked_Movies_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/lowest_ranked_movies_data.csv')
df
# Out:
#     rank                                           name  year certification  \
# 0      1                                 Disaster Movie  2008         PG-13
# 1      2                       Manos: The Hands of Fate  1966     Not Rated
# 2      3                     Birdemic: Shock and Terror  2010     Not Rated
# 3      4                   Superbabies: Baby Geniuses 2  2004            PG
# 4      5                        The Hottie & the Nottie  2008         PG-13
# ..   ...                                            ...   ...           ...
# 95    96                                  The Love Guru  2008         PG-13
# 96    97                             The Hungover Games  2014             R
# 97    98  In the Name of the King: A Dungeon Siege Tale  2007         PG-13
# 98    99                                   The Avengers  1998         PG-13
# 99   100             The Flintstones in Viva Rock Vegas  2000            PG
#
# ...

# %%
df.columns
# Out:
# Index(['rank', 'name', 'year', 'certification', 'duration', 'rating',
#        'review_count', 'director', 'writer', 'genre', 'stars'],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     rank                                           name  year certification  \
# 0      1                                 Disaster Movie  2008         PG-13
# 1      2                       Manos: The Hands of Fate  1966     Not Rated
# 2      3                     Birdemic: Shock and Terror  2010     Not Rated
# 3      4                   Superbabies: Baby Geniuses 2  2004            PG
# 4      5                        The Hottie & the Nottie  2008         PG-13
# ..   ...                                            ...   ...           ...
# 95    96                                  The Love Guru  2008         PG-13
# 96    97                             The Hungover Games  2014             R
# 97    98  In the Name of the King: A Dungeon Siege Tale  2007         PG-13
# 98    99                                   The Avengers  1998         PG-13
# 99   100             The Flintstones in Viva Rock Vegas  2000            PG
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of     rank                                           name  year certification  \
# 0      1                                 Disaster Movie  2008         PG-13
# 1      2                       Manos: The Hands of Fate  1966     Not Rated
# 2      3                     Birdemic: Shock and Terror  2010     Not Rated
# 3      4                   Superbabies: Baby Geniuses 2  2004            PG
# 4      5                        The Hottie & the Nottie  2008         PG-13
# ..   ...                                            ...   ...           ...
# 95    96                                  The Love Guru  2008         PG-13
# 96    97                             The Hungover Games  2014             R
# 97    98  In the Name of the King: A Dungeon Siege Tale  2007         PG-13
# 98    99                                   The Avengers  1998         PG-13
# 99   100             The Flintstones in Viva Rock Vegas  2000            PG
#
# ...

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of     rank                                           name  year certification  \
# 0      1                                 Disaster Movie  2008         PG-13
# 1      2                       Manos: The Hands of Fate  1966     Not Rated
# 2      3                     Birdemic: Shock and Terror  2010     Not Rated
# 3      4                   Superbabies: Baby Geniuses 2  2004            PG
# 4      5                        The Hottie & the Nottie  2008         PG-13
# ..   ...                                            ...   ...           ...
# 95    96                                  The Love Guru  2008         PG-13
# 96    97                             The Hungover Games  2014             R
# 97    98  In the Name of the King: A Dungeon Siege Tale  2007         PG-13
# 98    99                                   The Avengers  1998         PG-13
# 99   100             The Flintstones in Viva Rock Vegas  2000            PG
#
# ...

# %%
df.columns
# Out:
# Index(['rank', 'name', 'year', 'certification', 'duration', 'rating',
#        'review_count', 'director', 'writer', 'genre', 'stars'],
#       dtype='object')

# %%
df.name
# Out:
# 0                                    Disaster Movie
# 1                          Manos: The Hands of Fate
# 2                        Birdemic: Shock and Terror
# 3                      Superbabies: Baby Geniuses 2
# 4                           The Hottie & the Nottie
#                           ...
# 95                                    The Love Guru
# 96                               The Hungover Games
# 97    In the Name of the King: A Dungeon Siege Tale
# 98                                     The Avengers
# 99               The Flintstones in Viva Rock Vegas
# Name: name, Length: 100, dtype: object

# %%
df[df.rating<=2]
# Out:
#     rank                                 name  year certification duration  \
# 0      1                       Disaster Movie  2008         PG-13   1h 27m
# 1      2             Manos: The Hands of Fate  1966     Not Rated   1h 10m
# 2      3           Birdemic: Shock and Terror  2010     Not Rated   1h 45m
# 3      4         Superbabies: Baby Geniuses 2  2004            PG   1h 28m
# 4      5              The Hottie & the Nottie  2008         PG-13   1h 31m
# 5      6      Kirk Cameron's Saving Christmas  2014            PG   1h 19m
# 9     10                                Radhe  2021         TV-MA   1h 49m
# 11    12                         Pledge This!  2006             R   1h 31m
# 14    15                               Race 3  2018     Not Rated   2h 40m
# 15    16                 From Justin to Kelly  2003            PG   1h 21m
# 16    17                           Foodfight!  2012            PG   1h 31m
# ...

# %%
df[df.rating==2]
# Out:
#     rank                                 name  year certification duration  \
# 4      5              The Hottie & the Nottie  2008         PG-13   1h 31m
# 38    39  Enes Batur: Imagination or Reality?  2018           NaN      NaN
#
#     rating review_count         director  \
# 4      2.0          39K   ['Tom Putnam']
# 38     2.0          56K  ['Kamil Cetin']
#
#                                                writer                  genre  \
# 4                                    ['Heidi Ferrer']  ['Comedy', 'Romance']
# 38  ['Enes Batur', 'Busra Nur Karahan', 'Enver Sül...             ['Comedy']
#
#                                                 stars
# 4   ['Paris Hilton', 'Joel David Moore', 'Christin...
# 38     ['Enes Batur', 'Bilal Hanci', 'Atakan Özyurt']

# %%
df[df.review_count>='40K']
# Out:
#     rank                                           name  year certification  \
# 0      1                                 Disaster Movie  2008         PG-13
# 7      8                                Son of the Mask  2005            PG
# 10    11                              Battlefield Earth  2000         PG-13
# 12    13                              Alone in the Dark  2005             R
# 13    14                           Dragonball Evolution  2009            PG
# 14    15                                         Race 3  2018     Not Rated
# 20    21                                          Gigli  2003             R
# 21    22                                     Date Movie  2006         PG-13
# 22    23                                           Cats  2019            PG
# 28    29                              Jaws: The Revenge  1987         PG-13
# 35    36                                    Left Behind  2014         PG-13
# ...

# %%
df.certification=='Not Rated'
# Out:
# 0     False
# 1      True
# 2      True
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: certification, Length: 100, dtype: bool

# %%
df[df.certification=='Not Rated']
# Out:
#     rank                                      name  year certification  \
# 1      2                  Manos: The Hands of Fate  1966     Not Rated
# 2      3                Birdemic: Shock and Terror  2010     Not Rated
# 14    15                                    Race 3  2018     Not Rated
# 18    19                            Turks in Space  2006     Not Rated
# 23    24                         Daniel the Wizard  2004     Not Rated
# 26    27  The Human Centipede III (Final Sequence)  2015     Not Rated
# 34    35                                Hobgoblins  1988     Not Rated
# 42    43         Santa Claus Conquers the Martians  1964     Not Rated
# 44    45          Winnie the Pooh: Blood and Honey  2023     Not Rated
# 48    49                     Student of the Year 2  2019     Not Rated
# 56    57                            Tees Maar Khan  2010     Not Rated
# 60    61                                    Gunday  2014     Not Rated
# ...

# %%
df.groupby(['name','year'])

# %%
top_writers = df.explode('writer').groupby('writer')['review_count'].sum().reset_index()
top_writers = top_writers.sort_values(by='review_count', ascending=False)
print("Top Writers based on Total Review Count:")
print(top_writers.head())
# Out:
# Top Writers based on Total Review Count:
#                                                writer          review_count
# 87  ['Writers', 'Tomasz Klimala', 'Tomasz Mandes',...                   96K
# 24               ['Jason Friedberg', 'Aaron Seltzer']  94K109K111K62K51K22K
# 52                                   ['Tommy Wiseau']                   94K
# 58  ['Writers', 'Ben Zook', 'Steve Koren', 'Adam S...                   89K
# 9   ['Corey Mandell', 'J.D. Shapiro', 'L. Ron Hubb...                   82K

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='certification', y='rating', data=df, order=['G', 'PG', 'PG-13', 'R', 'Not Rated'])
plt.xlabel('Movie Certification')
plt.ylabel('Movie Rating')
plt.title('Relationship between Movie Certification and Rating')
# Out:
# Text(0.5, 1.0, 'Relationship between Movie Certification and Rating')

# %%
stars_df = df['stars'].explode().reset_index(name='actor')
actor_counts = stars_df['actor'].value_counts().reset_index()
actor_counts.columns = ['Actor', 'Movie Count']
top_actors = actor_counts.head(10)
print("Top Starring Actors:")
print(top_actors)
# Out:
# Top Starring Actors:
#                                                Actor  Movie Count
# 0  ['Carmen Electra', 'Vanessa Lachey', 'Nicole P...            1
# 1  ['G.W. Bailey', 'George Gaynes', 'Michael Wins...            1
# 2  ['Tiger Shroff', 'Riteish Deshmukh', 'Shraddha...            1
# 3      ['Loni Anderson', 'Hulk Hogan', 'Jim Varney']            1
# 4  ['Beata Fido', 'Maciej Póltorak', 'Aldona Stru...            1
# 5  ['Pamela Anderson', 'Amir AboulEla', 'Adriana ...            1
# 6  ['Stephen Dorff', 'Natascha McElhone', 'Stephe...            1
# 7       ['Robin Shou', 'Talisa Soto', 'James Remar']            1
# 8  ['Til Schweiger', 'Emmanuelle Vaugier', 'Natal...            1
# 9  ['Arnold Stang', 'Arnold Schwarzenegger', 'Deb...            1

# %%
genres_df = df['genre'].explode().reset_index(name='genre')
genre_counts = genres_df['genre'].value_counts().reset_index()
genre_counts.columns = ['Genre', 'Movie Count']
top_genres = genre_counts.head(10)
print("Top Genres with Highest Frequency:")
print(top_genres)
# Out:
# Top Genres with Highest Frequency:
#                                 Genre  Movie Count
# 0                          ['Comedy']            7
# 1   ['Horror', 'Mystery', 'Thriller']            6
# 2   ['Action', 'Adventure', 'Sci-Fi']            5
# 3  ['Action', 'Adventure', 'Fantasy']            4
# 4   ['Adventure', 'Comedy', 'Family']            4
# 5   ['Action', 'Adventure', 'Comedy']            4
# 6                ['Action', 'Sci-Fi']            3
# 7                ['Comedy', 'Horror']            3
# 8  ['Adventure', 'Comedy', 'Fantasy']            3
# 9      ['Comedy', 'Horror', 'Sci-Fi']            2
