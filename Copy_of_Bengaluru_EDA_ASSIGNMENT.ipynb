# %% [markdown]
# <a href="https://colab.research.google.com/github/surendra3474/takeobds41/blob/main/Copy_of_Bengaluru_EDA_ASSIGNMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bengaluru HOusing Price Prediction Using EDA

# %% [markdown]
# coding challange

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path='/content/bengaluru_house_prices (1).csv'
df=pd.read_csv(path)
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %% [markdown]
# Assigning Indendent

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# ...

# %%
df.nunique()
# Out:
# area_type          4
# availability      81
# location        1305
# size              31
# society         2688
# total_sqft      2117
# bath              19
# balcony            4
# price           1994
# dtype: int64

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df.availability
# Out:
# 0               19-Dec
# 1        Ready To Move
# 2        Ready To Move
# 3        Ready To Move
# 4        Ready To Move
#              ...
# 13315    Ready To Move
# 13316    Ready To Move
# 13317    Ready To Move
# 13318           18-Jun
# 13319    Ready To Move
# Name: availability, Length: 13320, dtype: object

# %%
df.groupby(['availability','location']).price.agg(['min','max','mean'])
# Out:
#                                        min     max    mean
# availability  location
# 14-Jul        Kumbena Agrahara       43.71   43.71   43.71
# 14-Nov        Whitefield             43.71   43.71   43.71
# 15-Aug        Yelahanka              62.00   62.00   62.00
# 15-Dec        1st Block Jayanagar   130.00  130.00  130.00
# 15-Jun        Outer Ring Road East   97.00   97.00   97.00
# ...                                    ...     ...     ...
# Ready To Move singapura paradise    140.00  140.00  140.00
#               t.c palya             160.00  160.00  160.00
#               tc.palya               48.00   48.00   48.00
#               vinayakanagar         200.00  200.00  200.00
#               white field,kadugodi  275.00  275.00  275.00
#
# [2377 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df.groupby(['location','size','price']).price.agg(['min','max','mean'])

# %%
df[df.price>=50]
# Out:
#                   area_type   availability               location       size  \
# 1                Plot  Area  Ready To Move       Chikka Tirupathi  4 Bedroom
# 2            Built-up  Area  Ready To Move            Uttarahalli      3 BHK
# 3      Super built-up  Area  Ready To Move     Lingadheeranahalli      3 BHK
# 4      Super built-up  Area  Ready To Move               Kothanur      2 BHK
# 6      Super built-up  Area         18-May       Old Airport Road      4 BHK
# ...                     ...            ...                    ...        ...
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout      3 BHK
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar      4 BHK
#
# ...

# %%
df[df.availability=='Ready To Move']
# Out:
#                   area_type   availability               location       size  \
# 1                Plot  Area  Ready To Move       Chikka Tirupathi  4 Bedroom
# 2            Built-up  Area  Ready To Move            Uttarahalli      3 BHK
# 3      Super built-up  Area  Ready To Move     Lingadheeranahalli      3 BHK
# 4      Super built-up  Area  Ready To Move               Kothanur      2 BHK
# 5      Super built-up  Area  Ready To Move             Whitefield      2 BHK
# ...                     ...            ...                    ...        ...
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout      3 BHK
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
# ...

# %%
availability_distribution = df['availability'].value_counts().reset_index()
availability_distribution.columns = ['Availability Status', 'Count']
print("Distribution of Property Availability Status:")
print(availability_distribution)
# Out:
# Distribution of Property Availability Status:
#    Availability Status  Count
# 0        Ready To Move  10581
# 1               18-Dec    307
# 2               18-May    295
# 3               18-Apr    271
# 4               18-Aug    200
# ..                 ...    ...
# 76              15-Aug      1
# 77              17-Jan      1
# 78              16-Nov      1
# 79              16-Jan      1
# 80              14-Jul      1
#
# [81 rows x 2 columns]

# %%
availability_distribution = df['availability'].value_counts().reset_index()
availability_distribution.columns = ['Availability Status', 'Count']
print("Distribution of Property Availability Status:")
print(availability_distribution)
# Out:
# Distribution of Property Availability Status:
#    Availability Status  Count
# 0        Ready To Move  10581
# 1               18-Dec    307
# 2               18-May    295
# 3               18-Apr    271
# 4               18-Aug    200
# ..                 ...    ...
# 76              15-Aug      1
# 77              17-Jan      1
# 78              16-Nov      1
# 79              16-Jan      1
# 80              14-Jul      1
#
# [81 rows x 2 columns]

# %%
balcony_distribution = df['balcony'].value_counts().reset_index()
balcony_distribution.columns = ['Number of Balconies', 'Count']
print("Distribution of the Number of Balconies:")
print(balcony_distribution)
# Out:
# Distribution of the Number of Balconies:
#    Number of Balconies  Count
# 0                  2.0   5113
# 1                  1.0   4897
# 2                  3.0   1672
# 3                  0.0   1029
